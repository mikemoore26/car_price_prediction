# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

pd.pandas.set_option("display.max_columns",None)
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./data/CarPrice.csv
# ./data/train2.csv

# %%
data_ori = pd.read_csv("data/CarPrice.csv")
data = data_ori.copy()

# %%
data.shape
# Out:
# (205, 26)

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
target = "price"

# %%
num_f = [f for f in data.columns if data[f].dtype != "O"]
num_f.remove("car_ID")
df_num = data[num_f]
df_num
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# ...

# %%
for f in df_num.columns:
    print(f,f"unique value {len(df_num[f].unique())}")
# Out:
# symboling unique value 6
# wheelbase unique value 53
# carlength unique value 75
# carwidth unique value 44
# carheight unique value 49
# curbweight unique value 171
# enginesize unique value 44
# boreratio unique value 38
# stroke unique value 37
# compressionratio unique value 32
# horsepower unique value 59
# peakrpm unique value 23
# citympg unique value 29
# highwaympg unique value 30
# price unique value 189

# %%
cols = ['symboling','peakrpm','peakrpm','peakrpm']

for col in cols:
    plt.figure(figsize=(16,8))
    sns.barplot(data=df_num, y=target ,x=col)
    plt.title("Symboling vs price")
    plt.show()

# %%
for f in df_num.columns:
    plt.figure(figsize=(16,8))
    sns.boxplot(y=data[f])
    plt.title(f)
    plt.show()

# %%
for f in df_num.columns:
    if f != cols:
        df = df_num.copy()
        sns.scatterplot(data=df,x=f,y=target)
        plt.title(f)
        plt.xlabel(f)
        plt.ylabel(target)
        plt.show()

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df_num.drop(target,1).corr())
plt.show()

# %%
# lets investigate the discret data
dis_f = [f for f in num_f if len(data[f].unique()) < 25]
#dis_f.append(target)
data[dis_f]
# Out:
#      symboling  peakrpm
# 0            3     5000
# 1            3     5000
# 2            1     5000
# 3            2     5500
# 4            2     5500
# ..         ...      ...
# 200         -1     5400
# 201         -1     5300
# 202         -1     5500
# 203         -1     4800
# 204         -1     5400
#
# [205 rows x 2 columns]

# %%
cat_f= [f for f in data.columns if data[f].dtype == "O"]
df_cat = data[cat_f]
df_cat
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3                 audi 100 ls      gas        std       four        sedan
# 4                  audi 100ls      gas        std       four        sedan
# ..                        ...      ...        ...        ...          ...
# 200           volvo 145e (sw)      gas        std       four        sedan
# 201               volvo 144ea      gas      turbo       four        sedan
# 202               volvo 244dl      gas        std       four        sedan
# 203                 volvo 246   diesel      turbo       four        sedan
# 204               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation enginetype cylindernumber fuelsystem
# ...

# %%
for f in cat_f:
    print(f"{f}...{len(data[f].unique())}")
# Out:
# CarName...147
# fueltype...2
# aspiration...2
# doornumber...2
# carbody...5
# drivewheel...3
# enginelocation...2
# enginetype...7
# cylindernumber...7
# fuelsystem...8

# %%
for f in cat_f:
    if f != "CarName":
        df = data.copy()
        df.groupby(f)[target].mean().plot.bar()
        plt.title(f)
        plt.xlabel(f)
        plt.ylabel(target)
        plt.show()

# %%
data['Brand'] = data['CarName'].apply(lambda x : x.split(" ")[0])

# %%
data.Brand.value_counts()
# Out:
# toyota         31
# nissan         17
# mazda          15
# honda          13
# mitsubishi     13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# volkswagen      9
# bmw             8
# buick           8
# plymouth        7
# audi            7
# saab            6
# porsche         4
# isuzu           4
# alfa-romero     3
# chevrolet       3
# jaguar          3
# renault         2
# vw              2
# maxda           2
# toyouta         1
# Nissan          1
# mercury         1
# porcshce        1
# vokswagen       1
# Name: Brand, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.barplot(data=data,y="Brand",x=target)
# plt.xticks(rotation=45)
plt.title("brand vs price")
plt.show()

# %%
def clean_brand(name):
    if name == "toyouta":
        name = "toyota"
    
    if name == "maxda":
        name = "mazda"
        
    if name == "Nissan":
        name = "nissan"
        
    if name == "porcshce":
        name = "porsche"
        
    if name == "vokswagen" or name == "vw":
        name = "volkswagen"
        
    return name

# %%
data["Brand"] = data["Brand"].apply(lambda x: clean_brand(x))

# %%
data.Brand.value_counts()
# Out:
# toyota         32
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# subaru         12
# volkswagen     12
# peugeot        11
# volvo          11
# dodge           9
# bmw             8
# buick           8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: Brand, dtype: int64

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
plt.figure(figsize=(8,8))
sns.barplot(data=data,x="Brand",y=target)
plt.xticks(rotation=90)
plt.title("brand vs price")
plt.show()

# %%
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# ...

# %%
data.to_csv("data/train2.csv",index=False)
